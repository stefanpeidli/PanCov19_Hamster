# %%
######## snakemake preamble start (automatically inserted, do not edit) ########
import sys; sys.path.extend(['/fast/users/peidlis_c/work/miniconda/envs/py36/lib/python3.9/site-packages', '/fast/work/users/peidlis_c/projects/Cov19Hamster/Pan_Cov19/snakemake/../notebooks']); import pickle; snakemake = pickle.loads(b'\x80\x04\x95\xd5\x0b\x00\x00\x00\x00\x00\x00\x8c\x10snakemake.script\x94\x8c\tSnakemake\x94\x93\x94)\x81\x94}\x94(\x8c\x05input\x94\x8c\x0csnakemake.io\x94\x8c\nInputFiles\x94\x93\x94)\x81\x94(\x8cW/fast/work/users/peidlis_c/data/Cov19Hamster/PhoRob_timecourse/PhoRob_timecourse_all.h5\x94\x8cW/fast/work/users/peidlis_c/data/Cov19Hamster/MesAur_timecourse/MesAur_timecourse_all.h5\x94\x8c\\/fast/work/users/peidlis_c/data/Cov19Hamster/ExternalData/MelmsIzar290421/MelmsIzar290421.h5\x94\x8cZ/fast/work/users/peidlis_c/data/Cov19Hamster/ExternalData/RenZhang030221/RenZhang030221.h5\x94\x8cd/fast/work/users/peidlis_c/data/Cov19Hamster/ExternalData/SperanzaDeWit270121/SperanzaDeWit270121.h5\x94\x8c\\/fast/work/users/peidlis_c/data/Cov19Hamster/ExternalData/LiaoZhang120520/LiaoZhang120520.h5\x94\x8cj/fast/work/users/peidlis_c/data/Cov19Hamster/ExternalData/WautersLambrecht210121/WautersLambrecht210121.h5\x94\x8cV/fast/work/users/peidlis_c/data/Cov19Hamster/ExternalData/DeloreyRegev290421/lung.h5ad\x94\x8cf/fast/work/users/peidlis_c/data/Cov19Hamster/ExternalData/GrantWunderink110121/GrantWunderink110121.h5\x94\x8c^/fast/work/users/peidlis_c/data/Cov19Hamster/ExternalData/BostBronte050321/BostBronte050321.h5\x94\x8cZ/fast/work/users/peidlis_c/data/Cov19Hamster/ExternalData/ChuaEils290620/ChuaEils290620.h5\x94\x8ce/fast/work/users/peidlis_c/data/Cov19Hamster/ExternalData/EGA/WendischSander221221_EGAD00001006827.h5\x94\x8ce/fast/work/users/peidlis_c/data/Cov19Hamster/ExternalData/EGA/WendischSander221221_EGAD00001008161.h5\x94e}\x94(\x8c\x06_names\x94}\x94(\x8c\x05dwarf\x94K\x00N\x86\x94\x8c\x04gold\x94K\x01N\x86\x94\x8c\x0fMelmsIzar290421\x94K\x02N\x86\x94\x8c\x0eRenZhang030221\x94K\x03N\x86\x94\x8c\x13SperanzaDeWit270121\x94K\x04N\x86\x94\x8c\x0fLiaoZhang120520\x94K\x05N\x86\x94\x8c\x16WautersLambrecht210121\x94K\x06N\x86\x94\x8c\x12DeloreyRegev290421\x94K\x07N\x86\x94\x8c\x14GrantWunderink110121\x94K\x08N\x86\x94\x8c\x15BostBronte050321_data\x94K\tN\x86\x94\x8c\x0eChuaEils290620\x94K\nN\x86\x94\x8c\x18WendischSander221221_BAL\x94K\x0bN\x86\x94\x8c\x1bWendischSander221221_LIBGEX\x94K\x0cN\x86\x94u\x8c\x12_allowed_overrides\x94]\x94(\x8c\x05index\x94\x8c\x04sort\x94eh6\x8c\tfunctools\x94\x8c\x07partial\x94\x93\x94h\x06\x8c\x19Namedlist._used_attribute\x94\x93\x94\x85\x94R\x94(h<)}\x94\x8c\x05_name\x94h6sNt\x94bh7h:h<\x85\x94R\x94(h<)}\x94h@h7sNt\x94bh\x1ah\nh\x1ch\x0bh\x1eh\x0ch h\rh"h\x0eh$h\x0fh&h\x10h(h\x11h*h\x12h,h\x13h.h\x14h0h\x15h2h\x16ub\x8c\x06output\x94h\x06\x8c\x0bOutputFiles\x94\x93\x94)\x81\x94(\x8cV/fast/work/users/peidlis_c/data/Cov19Hamster/Cov19_merged_cross_species_commongenes.h5\x94\x8cS/fast/work/users/peidlis_c/data/Cov19Hamster/Cov19_merged_cross_species_allgenes.h5\x94\x8c)../figures/Datasets_overview_pieplots.pdf\x94e}\x94(h\x18}\x94h4]\x94(h6h7eh6h:h<\x85\x94R\x94(h<)}\x94h@h6sNt\x94bh7h:h<\x85\x94R\x94(h<)}\x94h@h7sNt\x94bub\x8c\x06params\x94h\x06\x8c\x06Params\x94\x93\x94)\x81\x94}\x94(h\x18}\x94h4]\x94(h6h7eh6h:h<\x85\x94R\x94(h<)}\x94h@h6sNt\x94bh7h:h<\x85\x94R\x94(h<)}\x94h@h7sNt\x94bub\x8c\twildcards\x94h\x06\x8c\tWildcards\x94\x93\x94)\x81\x94}\x94(h\x18}\x94h4]\x94(h6h7eh6h:h<\x85\x94R\x94(h<)}\x94h@h6sNt\x94bh7h:h<\x85\x94R\x94(h<)}\x94h@h7sNt\x94bub\x8c\x07threads\x94K\x01\x8c\tresources\x94h\x06\x8c\tResources\x94\x93\x94)\x81\x94(K\x01K\x01J\x00\xf4\x01\x00J\x00\xf4\x01\x00\x8c\x04/tmp\x94\x8c\x04128G\x94\x8c\x0802:00:00\x94e}\x94(h\x18}\x94(\x8c\x06_cores\x94K\x00N\x86\x94\x8c\x06_nodes\x94K\x01N\x86\x94\x8c\x06mem_mb\x94K\x02N\x86\x94\x8c\x07disk_mb\x94K\x03N\x86\x94\x8c\x06tmpdir\x94K\x04N\x86\x94\x8c\x03mem\x94K\x05N\x86\x94\x8c\x04time\x94K\x06N\x86\x94uh4]\x94(h6h7eh6h:h<\x85\x94R\x94(h<)}\x94h@h6sNt\x94bh7h:h<\x85\x94R\x94(h<)}\x94h@h7sNt\x94bh\x80K\x01h\x82K\x01h\x84J\x00\xf4\x01\x00h\x86J\x00\xf4\x01\x00h\x88h{h\x8ah|h\x8ch}ub\x8c\x03log\x94h\x06\x8c\x03Log\x94\x93\x94)\x81\x94\x8cHlogs/notebooks/Cov19Hamster_Integration_Data_Preparation_processed.ipynb\x94a}\x94(h\x18}\x94\x8c\x08notebook\x94K\x00N\x86\x94sh4]\x94(h6h7eh6h:h<\x85\x94R\x94(h<)}\x94h@h6sNt\x94bh7h:h<\x85\x94R\x94(h<)}\x94h@h7sNt\x94bh\x9eh\x9bub\x8c\x06config\x94}\x94\x8c\x04rule\x94\x8c\x13merge_cross_species\x94\x8c\x0fbench_iteration\x94N\x8c\tscriptdir\x94\x8cQ/fast/work/users/peidlis_c/projects/Cov19Hamster/Pan_Cov19/snakemake/../notebooks\x94ub.'); from snakemake.logging import logger; logger.printshellcmds = False; import os; os.chdir(r'/fast/work/users/peidlis_c/projects/Cov19Hamster/Pan_Cov19/snakemake');
######## snakemake preamble end #########

# %%
from IPython.display import clear_output
import matplotlib.backends.backend_pdf
from tqdm.notebook import tqdm
import scanpy as sc
import matplotlib.pyplot as pl
import anndata as ad
import pandas as pd
import numpy as np
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:99% !important; }</style>"))
# %matplotlib inline
import scvelo as scv
scv.settings.verbosity=1

import os
at_home = False if '/fast/work/users/' in os.getcwd() else True
signatures_path = '/home/peidli/utils/scrnaseq_signature_collection/' if at_home else '/fast/work/users/peidlis_c/utils/scrnaseq_signature_collection/'
tmp_path = '/fast/scratch/users/peidlis_c/tmp/'
import sys
utils_path = '/extra/stefan/utils/scrnaseq_utils/' if at_home else '/fast/work/users/peidlis_c/utils/single_cell_rna_seq/scrnaseq_utils/'
sys.path.insert(1, utils_path)
from scrnaseq_util_functions import *
data_path = '/extra/stefan/public_data/' if at_home else '/fast/work/users/peidlis_c/data/'
# Out:
# <style>.container { width:99% !important; }</style>

# %% [markdown]
# - DASO: days after symptom onset
# - DAIS: days after intubation start

# %% [markdown]
# # Load data

# %%
DIR = '/fast/work/users/peidlis_c/data/Cov19Hamster/'
# hamster data
dwarf_dexab = DIR + 'PhoRob_DexAb/DexAb_combined_integrated_loomed.h5'
dwarf_timecourse = DIR + 'PhoRob_timecourse/PhoRob_timecourse_all.h5'
gold_timecourse = DIR + 'MesAur_timecourse/MesAur_timecourse_all.h5'
# other data
MelmsIzar290421 = DIR + 'ExternalData/MelmsIzar290421/MelmsIzar290421.h5'
RenZhang030221 = DIR + 'ExternalData/RenZhang030221/RenZhang030221.h5'
SperanzaDeWit270121 = DIR + 'ExternalData/SperanzaDeWit270121/SperanzaDeWit270121.h5'
LiaoZhang120520 = DIR + 'ExternalData/LiaoZhang120520/LiaoZhang120520.h5'
WautersLambrecht210121 = DIR + 'ExternalData/WautersLambrecht210121/WautersLambrecht210121.h5'
DeloreyRegev290421 = DIR + 'ExternalData/DeloreyRegev290421/lung.h5ad'
GrantWunderink110121 = DIR + "ExternalData/GrantWunderink110121/GrantWunderink110121.h5"
BostBronte050321 = DIR + "ExternalData/BostBronte050321/BostBronte050321.h5"
ChuaEils290620 = DIR + "ExternalData/ChuaEils290620/ChuaEils290620.h5"
WendischSander221221 = DIR + "ExternalData/EGA/"

# %%
WautersLambrecht210121_data = sc.read(WautersLambrecht210121)
WautersLambrecht210121_data.obs = WautersLambrecht210121_data.obs.rename({'PatientNumber': 'sample_id', 'PatientType': 'severity', 'Disease': 'disease', 'CellType': 'celltype'}, axis=1)
WautersLambrecht210121_data.obs.disease = WautersLambrecht210121_data.obs.disease.cat.rename_categories({'control': 'pneumonia'})
WautersLambrecht210121_data.obs['organism'] = 'human'
WautersLambrecht210121_data.obs['sample_type'] = 'BALF'
WautersLambrecht210121_data.uns['name'] = 'WautersLambrecht210121'
WautersLambrecht210121_data.obs.severity = ['severe' if x=='Ward' else 'critcal' if x=='ICU' else 'unknown' for x in WautersLambrecht210121_data.obs.severity]
WautersLambrecht210121_data.obs = WautersLambrecht210121_data.obs.drop(['n_counts', 'condition'], axis=1)  # remove duplicate
WautersLambrecht210121_data.obs.head()
# Out:
#                           patient severity  disease   celltype  ncounts  \
# BAL009_AAACCTGAGCTAGCCC-1  BAL009   severe  COVID19   Ciliated  13937.0
# BAL009_AAACCTGTCACATACG-1  BAL009   severe  COVID19   Ciliated    591.0
# BAL009_AAACGGGAGGGCTTCC-1  BAL009   severe  COVID19   Ciliated    324.0
# BAL009_AACCGCGAGGTCATCT-1  BAL009   severe  COVID19  Secretory   8795.0
# BAL009_AACCGCGGTCGCCATG-1  BAL009   severe  COVID19   Ciliated    407.0
#
#                            ngenes  percent_mito  percent_ribo  percent_hemo  \
# BAL009_AAACCTGAGCTAGCCC-1    4217      0.078496      0.087824      0.000215
# BAL009_AAACCTGTCACATACG-1     414      0.074450      0.059222      0.000000
# BAL009_AAACGGGAGGGCTTCC-1     255      0.040123      0.012346      0.000000
# BAL009_AACCGCGAGGTCATCT-1    2130      0.000000      0.149858      0.000000
# BAL009_AACCGCGGTCGCCATG-1     302      0.029484      0.054054      0.000000
#
#                           organism sample_type
# ...

# %%
LiaoZhang120520_data = sc.read(LiaoZhang120520)
LiaoZhang120520_data.obs['severity'] = ['mild' if 'mild' in x else 'severe' if 'severe' in x else None for x in LiaoZhang120520_data.obs.condition]
LiaoZhang120520_data.obs['disease'] = ['healthy' if x=='healthy' else 'COVID19' for x in LiaoZhang120520_data.obs.condition]
LiaoZhang120520_data.obs=LiaoZhang120520_data.obs.rename({'patient': 'sample_id', 'celltype_fine': 'celltype_2'}, axis=1)
LiaoZhang120520_data.obs['organism'] = 'human'
LiaoZhang120520_data.obs = LiaoZhang120520_data.obs.drop(['n_counts', 'condition'], axis=1)  # remove duplicate
LiaoZhang120520_data.obs['sample_type'] = 'BALF'
LiaoZhang120520_data.uns['name'] = 'LiaoZhang120520'
LiaoZhang120520_data.obs.head()
# Out:
#                        sample_id  ncounts  ngenes  percent_mito  percent_ribo  \
# AAACCTGAGATATACG-1-C52       C52   2018.0   786.0      0.019822      0.325570
# AAACCTGAGCGTGAAC-1-C52       C52   3479.0  1028.0      0.022420      0.226789
# AAACCTGAGCTACCTA-1-C52       C52   2449.0   928.0      0.017150      0.235198
# AAACCTGAGGCTAGCA-1-C52       C52   3181.0  1013.0      0.011317      0.176045
# AAACCTGAGGGCTCTC-1-C52       C52   2508.0   878.0      0.025518      0.232456
#
#                         percent_hemo     celltype celltype_2 severity  \
# AAACCTGAGATATACG-1-C52           0.0  Macrophages     Group4     None
# AAACCTGAGCGTGAAC-1-C52           0.0  Macrophages     Group4     None
# AAACCTGAGCTACCTA-1-C52           0.0  Macrophages     Group4     None
# AAACCTGAGGCTAGCA-1-C52           0.0  Macrophages     Group4     None
# AAACCTGAGGGCTCTC-1-C52           0.0  Macrophages     Group4     None
#
#                         disease organism sample_type
# ...

# %%
SperanzaDeWit270121_data = sc.read(SperanzaDeWit270121)
SperanzaDeWit270121_data.obs = SperanzaDeWit270121_data.obs.rename({'patient': 'sample_id'}, axis=1)
SperanzaDeWit270121_data.obs['disease'] = ['irradiated COVID19' if 'irradiated' in x else 'COVID19' for x in SperanzaDeWit270121_data.obs.condition]
SperanzaDeWit270121_data.obs = SperanzaDeWit270121_data.obs.drop(['n_counts', 'condition'], axis=1)  # remove duplicate
SperanzaDeWit270121_data.obs['severity'] = 'mild'
SperanzaDeWit270121_data.obs['sample_type'] = 'tissue'
SperanzaDeWit270121_data.uns['name'] = 'SperanzaDeWit270121'
SperanzaDeWit270121_data.obs.head()
# Out:
#                          sample_id              organism  ncounts  ngenes  \
# AAACCCAAGGCATCAG-1-16436     16436  African green monkey   1664.0     871
# AAACCCAGTGGGCTTC-1-16436     16436  African green monkey    609.0     378
# AAACCCATCTCTAAGG-1-16436     16436  African green monkey   1428.0     717
# AAACGAAAGCACGGAT-1-16436     16436  African green monkey   1363.0     690
# AAACGAAAGGTACCTT-1-16436     16436  African green monkey   5222.0    1592
#
#                           percent_mito  percent_ribo  percent_hemo  \
# AAACCCAAGGCATCAG-1-16436      0.009014      0.044471           0.0
# AAACCCAGTGGGCTTC-1-16436      0.009852      0.008210           0.0
# AAACCCATCTCTAAGG-1-16436      0.013305      0.088235           0.0
# AAACGAAAGCACGGAT-1-16436      0.013206      0.079237           0.0
# AAACGAAAGGTACCTT-1-16436      0.003638      0.057449           0.0
#
#                                      disease severity sample_type
# ...

# %%
RenZhang030221_data = sc.read(RenZhang030221)
RenZhang030221_data.obs = RenZhang030221_data.obs.rename({'patient': 'sample_id', 'celltype_fine': 'celltype_2', 'COVID-19-related medication and anti-microbials': 'treatment',
                                                         'Datasets' : 'sample_batch', 'Single cell sequencing platform': '3_or_5_prime', 'Outcome': 'outcome', 'Age': 'age', 
                                                          'Sex': 'sex', 'Comorbidities': 'comorbidities', 'Sampling day (Days after symptom onset)': 'DASO'}, axis=1)
RenZhang030221_data.obs['severity'] = [x.split(' ')[0] for x in RenZhang030221_data.obs.condition]
RenZhang030221_data.obs['disease'] = 'COVID19'
RenZhang030221_data.obs.sex=RenZhang030221_data.obs.sex.cat.rename_categories({'F': 'female', 'M': 'male'})
RenZhang030221_data.obs = RenZhang030221_data.obs.drop(['n_counts', 'condition'], axis=1)  # remove duplicate
RenZhang030221_data.obs['organism'] = 'human'
RenZhang030221_data.obs['3_or_5_prime']=RenZhang030221_data.obs['3_or_5_prime'].cat.rename_categories({"10X 3'": '3', "10X 5'": '5'})
RenZhang030221_data.uns['name'] = 'RenZhang030221'
RenZhang030221_data.obs.head()
# Out:
#                            celltype_2 celltype sample_id sample_batch age  \
# AAACCTGAGATGTCGG-95   T_gdT_c14-TRDV2      CD8    P-M074      Batch07  36
# AAACCTGAGGCTCATT-95     Macro_c1-C1QC    Macro    P-M074      Batch07  36
# AAACCTGCAATCCGAT-95   Macro_c4-DNAJB1    Macro    P-M074      Batch07  36
# AAACCTGGTTTAGCTG-95  T_CD8_c07-TYROBP      CD8    P-M074      Batch07  36
# AAACCTGTCAATCACG-95        DC_c2-CD1C       DC    P-M074      Batch07  36
#
#                       sex DASO 3_or_5_prime     outcome comorbidities  \
# AAACCTGAGATGTCGG-95  male   11            5  discharged          none
# AAACCTGAGGCTCATT-95  male   11            5  discharged          none
# AAACCTGCAATCCGAT-95  male   11            5  discharged          none
# AAACCTGGTTTAGCTG-95  male   11            5  discharged          none
# AAACCTGTCAATCACG-95  male   11            5  discharged          none
#
#                                              treatment sample_type  ncounts  \
# ...

# %%
MelmsIzar290421_data = sc.read(MelmsIzar290421)
MelmsIzar290421_data.obs['organism'] = 'human'
MelmsIzar290421_data.obs = MelmsIzar290421_data.obs.rename({'biosample_id': 'sample_id', 'cell_type_intermediate' : 'celltype', 'cell_type_fine': 'celltype_2', 'intubation_days': 'DAIS'}, axis=1)
MelmsIzar290421_data.obs['severity'] = 'critical'
MelmsIzar290421_data.obs['sample_type'] = 'tissue'
MelmsIzar290421_data.obs['outcome'] = 'deceased'
MelmsIzar290421_data.obs['3_or_5_prime']='3'
MelmsIzar290421_data.obs = MelmsIzar290421_data.obs.drop(['disease'], axis=1)  # remove duplicate
MelmsIzar290421_data.obs['disease'] = ['healthy' if x=='Control' else 'COVID19' for x in MelmsIzar290421_data.obs['group']]
MelmsIzar290421_data.obs = MelmsIzar290421_data.obs.drop(['n_counts', 'organ', 'library_preparation_protocol', 'disease__ontology_label', 'group', 'library_preparation_protocol__ontology_label',
                                                         'organ__ontology_label', 'species__ontology_label', 'species', 'donor_id', 'cell_type_main', 'initial_clustering', 'pmi_h'], axis=1)  # remove duplicate
MelmsIzar290421_data.uns['name'] = 'MelmsIzar290421'
MelmsIzar290421_data.obs.head()
# Out:
#                      sample_id     celltype            celltype_2 age     sex  \
# GTTACAGCACCCAAGC-1_4    C54ctr          AT1                   AT1  72  female
# TCAATTCTCCAGGACC-1_4    C54ctr  Macrophages  Alveolar macrophages  72  female
# CACGAATTCTCAGGCG-1_4    C54ctr  Macrophages  Alveolar macrophages  72  female
# CACTAAGTCAACCCGG-1_4    C54ctr  Fibroblasts       Pathological FB  72  female
# GCCGATGCATCCTTGC-1_4    C54ctr          AT1                   AT1  72  female
#
#                      recorded_race recorded_ethnicity DAIS  \
# GTTACAGCACCCAAGC-1_4         Asian       not_hispanic  nan
# TCAATTCTCCAGGACC-1_4         Asian       not_hispanic  nan
# CACGAATTCTCAGGCG-1_4         Asian       not_hispanic  nan
# CACTAAGTCAACCCGG-1_4         Asian       not_hispanic  nan
# GCCGATGCATCCTTGC-1_4         Asian       not_hispanic  nan
#
#                      interval_death_symptoms_onset_days     ncounts  ngenes  \
# ...

# %%
DeloreyRegev290421_data = sc.read(DeloreyRegev290421)
DeloreyRegev290421_data.obs['severity'] = 'critical'
DeloreyRegev290421_data.obs['disease'] = 'COVID19'
DeloreyRegev290421_data.obs=DeloreyRegev290421_data.obs.rename({'donor': 'sample_id', 'SubCluster': 'celltype_2', 'Cluster': 'celltype', 'n_UMI': 'ncounts', 'n_genes': 'ngenes',
                                                               'Viral+': 'SCov2_detected'}, axis=1)
DeloreyRegev290421_data.obs['organism'] = 'human'
DeloreyRegev290421_data.obs = DeloreyRegev290421_data.obs.drop(['leiden_res_2', 'leiden_res_1.3', 'compartment', 'predicted_celltype', 'method'], axis=1)  # remove duplicate
DeloreyRegev290421_data.obs['sample_type'] = 'tissue'
DeloreyRegev290421_data.obs['outcome'] = 'deceased'
DeloreyRegev290421_data.uns['name'] = 'DeloreyRegev290421'
DeloreyRegev290421_data.obs_names_make_unique()
DeloreyRegev290421_data.obs.head()
# Out:
#                                       ngenes  ncounts  percent_mito  doublet  \
# barcodekey
# 02-P005175-S053-R01-GTTTGGAGTATCAAGA    2302     3874      1.445534    False
# 02-P005175-S053-R01-TGCAGTAAGCAGATAT    2286     3726      0.053677    False
# 02-P005175-S053-R01-CCCTAACCACTACCGG    1799     2904      0.068871    False
# 02-P005175-S053-R01-TCCGAAAAGGTATCTC    1276     1925      0.103896    False
# 02-P005175-S053-R01-TGCACGGTCTCGGCTT    1147     1742      0.229621    False
#
#                                          celltype    celltype_2  \
# barcodekey
# 02-P005175-S053-R01-GTTTGGAGTATCAAGA  Endothelial  Lymphatic EC
# 02-P005175-S053-R01-TGCAGTAAGCAGATAT  Endothelial  Lymphatic EC
# 02-P005175-S053-R01-CCCTAACCACTACCGG  Endothelial  Lymphatic EC
# 02-P005175-S053-R01-TCCGAAAAGGTATCTC  Endothelial  Lymphatic EC
# 02-P005175-S053-R01-TGCACGGTCTCGGCTT  Endothelial  Lymphatic EC
#
#                                       SCov2_detected sample_id  disease  \
# barcodekey
# ...

# %%
GrantWunderink110121_data = sc.read(GrantWunderink110121)
GrantWunderink110121_data.var=GrantWunderink110121_data.var.drop(GrantWunderink110121_data.var.columns, axis=1)  # redundant stuff
GrantWunderink110121_data.obs['Sample type'] = 'BALF'
GrantWunderink110121_data.obs=GrantWunderink110121_data.obs.rename({'Patient': 'sample_id', 'Sample type': 'sample_type', 'Cluster': 'celltype_2', 'No of SARS-CoV-2 genes': 'SCoV2_sum', 
                                                                    'COVID-19': 'disease', 'Sample status': 'fresh_or_frozen', 'Day after intubation': 'DAIS',
                                                                    'No of genes': 'ngenes', 'No of UMIs': 'ncounts', '% of mito genes': 'percent_mito', '% of ribo genes': 'percent_ribo'
                                                                   }, axis=1)
GrantWunderink110121_data.obs['disease'] = ['COVID19' if x=='True' else 'healthy' for x in GrantWunderink110121_data.obs['disease']]
GrantWunderink110121_data.obs['organism'] = 'human'
GrantWunderink110121_data.obs['severity'] = 'critical'
GrantWunderink110121_data.obs['SCoV2_detected'] = GrantWunderink110121_data.obs['SCoV2_sum'] > 0
GrantWunderink110121_data.uns['name'] = 'GrantWunderink110121'
GrantWunderink110121_data.obs = GrantWunderink110121_data.obs.drop(['Sample', 'IFNA Response', 'IFNG Response', 'n_counts'], axis=1)
GrantWunderink110121_data.obs.head()
# Out:
#                    sample_id  DAIS sample_type fresh_or_frozen  \
# AAACCTGAGACTTTCG-7         6   1.0        BALF           Fresh
# AAACCTGAGGCTACGA-7         6   1.0        BALF           Fresh
# AAACCTGAGGGATGGG-7         6   1.0        BALF           Fresh
# AAACCTGCAATGTTGC-7         6   1.0        BALF           Fresh
# AAACCTGCACGACGAA-7         6   1.0        BALF           Fresh
#
#                         celltype_2  disease  SCoV2_sum  ngenes  ncounts  \
# AAACCTGAGACTTTCG-7           TRAM1  healthy        0.0  3541.0  16737.0
# AAACCTGAGGCTACGA-7           TRAM1  healthy        0.0  3196.0  12604.0
# AAACCTGAGGGATGGG-7  CD4 CM T cells  healthy        0.0  1009.0   1973.0
# AAACCTGCAATGTTGC-7           TRAM1  healthy        0.0  2933.0  10889.0
# AAACCTGCACGACGAA-7           TRAM1  healthy        0.0  2361.0   7663.0
#
#                     percent_mito  percent_ribo organism  severity  \
# AAACCTGAGACTTTCG-7      3.537074     12.803967    human  critical
# ...

# %%
BostBronte050321_data = sc.read(BostBronte050321)
BostBronte050321_data.obs['tissue'] = 'BALF'
BostBronte050321_data.obs=BostBronte050321_data.obs.rename({'subject id': 'sample_id', 'tissue': 'sample_type', 'clinical outcome': 'outcome', 'Sex': 'sex'}, axis=1)
BostBronte050321_data.obs['disease'] = 'COVID19'
BostBronte050321_data.obs['organism'] = 'human'
BostBronte050321_data.obs['severity'] = 'severe'
BostBronte050321_data.uns['name'] = 'BostBronte050321_data'
BostBronte050321_data.obs['outcome'].cat.rename_categories({'Alive': 'discharged', 'Dead': 'deceased'}, inplace=True)
BostBronte050321_data.obs = BostBronte050321_data.obs.drop(['source_name', 'clinic status', 'n_counts', 'n_genes'], axis=1)
BostBronte050321_data.obs.head()
# Out:
#                         sample_type  sample_id sofa score age     sex  \
# barcode
# AAACCCAGTCCAAAGG-1-BAL6        BALF  Patient 6          6  59  female
# AAACGCTCAAGTGGAC-1-BAL6        BALF  Patient 6          6  59  female
# AAACGCTTCATTTCGT-1-BAL6        BALF  Patient 6          6  59  female
# AAAGAACTCCCGTTGT-1-BAL6        BALF  Patient 6          6  59  female
# AAAGGATTCGTTTACT-1-BAL6        BALF  Patient 6          6  59  female
#
#                             outcome  ncounts  ngenes  percent_mito  \
# barcode
# AAACCCAGTCCAAAGG-1-BAL6  discharged   2604.0    1013      0.293395
# AAACGCTCAAGTGGAC-1-BAL6  discharged   9248.0    2110      0.067690
# AAACGCTTCATTTCGT-1-BAL6  discharged  16176.0    3965      0.049209
# AAAGAACTCCCGTTGT-1-BAL6  discharged   1115.0     544      0.021525
# AAAGGATTCGTTTACT-1-BAL6  discharged   1314.0     501      0.059361
#
#                          percent_ribo  percent_hemo  disease organism severity
# barcode
# ...

# %%
ChuaEils290620_data = sc.read(ChuaEils290620)
ChuaEils290620_data.obs['sample_type'] = ['BALF' if x=='BL' else 'Nasal Swap' if x=='NS' else 'Protected Specimen Brush' for x in ChuaEils290620_data.obs.location]
ChuaEils290620_data.obs = ChuaEils290620_data.obs.drop(['orig.ident', 'nCount_RNA', 'nFeature_RNA', 'percent.mt', 'virus_pos', 'series', 'location', 'infection'], axis=1)
ChuaEils290620_data.obs = ChuaEils290620_data.obs.rename({'dps': 'DASO', 'sample': 'sample_id'}, axis=1)
ChuaEils290620_data.obs['organism'] = 'human'
ChuaEils290620_data.obs['disease'] = 'COVID19'
ChuaEils290620_data.uns['name'] = 'ChuaEils290620'
ChuaEils290620_data.obs.head()
# Out:
#                                         sample_id     patient sex   age  \
# AAACCCAAGATACGAT-BIH-CoV-10_NS_1  BIH-CoV-10_NS_1  BIH-CoV-10   m  68.0
# AAACCCAAGCAGTCTT-BIH-CoV-10_NS_1  BIH-CoV-10_NS_1  BIH-CoV-10   m  68.0
# AAAGAACAGTCATCGT-BIH-CoV-10_NS_1  BIH-CoV-10_NS_1  BIH-CoV-10   m  68.0
# AAAGAACCAGCAGTTT-BIH-CoV-10_NS_1  BIH-CoV-10_NS_1  BIH-CoV-10   m  68.0
# AAAGGATAGCAATTAG-BIH-CoV-10_NS_1  BIH-CoV-10_NS_1  BIH-CoV-10   m  68.0
#
#                                    celltype  severity  DASO  ncounts  ngenes  \
# AAACCCAAGATACGAT-BIH-CoV-10_NS_1     B cell  critical  20.0   7037.0    2200
# AAACCCAAGCAGTCTT-BIH-CoV-10_NS_1        NaN  critical  20.0   2130.0    1091
# AAAGAACAGTCATCGT-BIH-CoV-10_NS_1   Squamous  critical  20.0   3120.0    1656
# AAAGAACCAGCAGTTT-BIH-CoV-10_NS_1   Ciliated  critical  20.0   2735.0    1516
# AAAGGATAGCAATTAG-BIH-CoV-10_NS_1  Secretory  critical  20.0  15260.0    2857
#
# ...

# %%
WendischSander221221_BAL = sc.read(f'{WendischSander221221}WendischSander221221_EGAD00001006827.h5')
WendischSander221221_BAL.obs = WendischSander221221_BAL.obs.rename({'library': 'sample_id', 'gender': 'sex', 'day after onset': 'DASO', 'Celltype': 'celltype', 'immuno_modulators': 'treatment'}, axis=1)
WendischSander221221_BAL.obs=WendischSander221221_BAL.obs.drop(['used in manuscript', 'percent_hemo'], axis=1)
WendischSander221221_BAL.obs.head()
# Out:
#                        sample_id  ncounts  ngenes  percent_mito  percent_ribo  \
# AAACGCTCAACTGTGT-BAL-8     BAL-8  25796.0  4846.0      0.061056      0.136882
# AAACGCTCATCGTCCT-BAL-8     BAL-8   8083.0  2288.0      0.048992      0.308054
# AAACGCTTCTCGCTCA-BAL-8     BAL-8   2998.0  1377.0      0.005337      0.019013
# AAAGGATCAATTCTTC-BAL-8     BAL-8  15040.0  4012.0      0.094947      0.167154
# AAAGGATCACGGAAGT-BAL-8     BAL-8  12545.0  3644.0      0.043523      0.120207
#
#                         n_counts  disease severity sample_type organism  ...  \
# AAACGCTCAACTGTGT-BAL-8   25792.0  COVID19   severe        BALF    human  ...
# AAACGCTCATCGTCCT-BAL-8    8083.0  COVID19   severe        BALF    human  ...
# AAACGCTTCTCGCTCA-BAL-8    2998.0  COVID19   severe        BALF    human  ...
# AAAGGATCAATTCTTC-BAL-8   15039.0  COVID19   severe        BALF    human  ...
# AAAGGATCACGGAAGT-BAL-8   12544.0  COVID19   severe        BALF    human  ...
#
# ...

# %%
WendischSander221221_LIBGEX = sc.read(f'{WendischSander221221}WendischSander221221_EGAD00001008161.h5')
WendischSander221221_LIBGEX.obs['treatment'] = 'likely dexamethasone'
WendischSander221221_LIBGEX.obs = WendischSander221221_LIBGEX.obs.rename({'library': 'sample_id'}, axis=1)
WendischSander221221_LIBGEX.obs=WendischSander221221_LIBGEX.obs.drop(['percent_hemo'], axis=1)
WendischSander221221_LIBGEX.obs.head()
# Out:
#                                       sample_id  ncounts  ngenes  \
# AAACCCACACAGTGAG-BAL_26_lib_GEX  BAL_26_lib_GEX   5895.0    2094
# AAACCCATCAACCCGG-BAL_26_lib_GEX  BAL_26_lib_GEX   3933.0     476
# AAACCCATCCACGGAC-BAL_26_lib_GEX  BAL_26_lib_GEX  17633.0    4493
# AAACGAAAGCCTCACG-BAL_26_lib_GEX  BAL_26_lib_GEX   3658.0    1756
# AAACGAAAGCGAGAAA-BAL_26_lib_GEX  BAL_26_lib_GEX  36305.0    5652
#
#                                  percent_mito  percent_ribo  n_counts  \
# AAACCCACACAGTGAG-BAL_26_lib_GEX      0.062935      0.189313    5892.0
# AAACCCATCAACCCGG-BAL_26_lib_GEX      0.794559      0.031274    3933.0
# AAACCCATCCACGGAC-BAL_26_lib_GEX      0.051154      0.098565   17632.0
# AAACGAAAGCCTCACG-BAL_26_lib_GEX      0.089393      0.092400    3657.0
# AAACGAAAGCGAGAAA-BAL_26_lib_GEX      0.086159      0.130313   36305.0
#
#                                  disease     severity sample_type organism  \
# ...

# %%
# MesAur
if True:
    gold_data = scv.read(gold_timecourse)
    gold_data.uns['name'] = 'Goldhamster'
    gold_data.obs['organism'] = 'Goldhamster'
    gold_data.obs['disease'] = ['healthy' if x=='d0' else 'recovered COVID19' if x=='e14' else 'COVID19' for x in gold_data.obs.timepoint]
    gold_data.obs['dosage'] = ['no dose' if x=='d0' else 'high dose' for x in gold_data.obs['timepoint']]  # high dose
    gold_data.uns['dosage_colors'] = ['tab:red', 'tab:grey']  # high, no dose
    gold_data.obs['time'] = [x.upper() for x in gold_data.obs.timepoint]
    gold_data.uns['time_colors'] = ['tab:grey', 'lightgreen', 'limegreen', 'darkgreen', 'black']  # D0, D2, D3, d5, e14
    gold_data.obs['timepoint'] = ['hd_'+x if x!='D0' else x for x in gold_data.obs.time]
    gold_data.obs['hamster'] = [x+'_ma' for x in gold_data.obs.hamster]
    gold_data.obs['severity'] = 'mild'
    gold_data.obs['sample_type'] = 'tissue'
    gold_data.obs['3_or_5_prime'] = '3'
    gold_data.obs['disease'] = 'COVID19'
    gold_data.obs['SCoV2_detected'] = gold_data.obs['SCoV2_sum'] > 0
    gold_data.obs['sample_id'] = [x+'_'+y for x,y in zip(gold_data.obs.hamster, gold_data.obs.timepoint)]
    gold_data.obs = gold_data.obs.drop(['orig.ident', 'integrated_snn_res.0.5', 'seurat_clusters', 'nCount_SCT', 'nFeature_SCT', 'UMAP_1', 'UMAP_2', 'cell_id', 'endocytotox', 'n_counts'], axis=1)
    gold_data.obs=gold_data.obs.rename({'nCount_RNA': 'ncounts', 'nFeature_RNA': 'ngenes', 'percent.mt': 'percent_mito'}, axis=1)

    # humanize genes
    gold_data.var_names = [x.upper() for x in gold_data.var_names]
    # gold_data.var_names = specify_genes(gold_data.var_names)
    # gold_data = aggregate_duplicate_genes(gold_data)
    # gold_data.write(f'{data_path}MesAur_timecourse/MesAur_timecourse_all_humanized.h5')
else:
    gold_data = sc.read(f'{data_path}MesAur_timecourse/MesAur_timecourse_all_humanized.h5')
print(gold_data.X.shape, gold_data.X.count_nonzero())
gold_data.obs.head()
# Out:
# (43972, 36168) 100867360
#                                  ncounts  ngenes timepoint hamster  SCoV2_sum  \
# ma_d0_lung_1_AAACCCAGTGACTCGC-1   1564.0  1013.0        D0  Ha1_ma        0.0
# ma_d0_lung_1_AAACGAAAGGATTCCT-1   1940.0   850.0        D0  Ha1_ma        0.0
# ma_d0_lung_1_AAACGAACAAGACAAT-1   4112.0  1466.0        D0  Ha1_ma        0.0
# ma_d0_lung_1_AAACGCTAGACAAGCC-1  20028.0  4750.0        D0  Ha1_ma        0.0
# ma_d0_lung_1_AAACGCTAGTATAGGT-1  28324.0  5941.0        D0  Ha1_ma        0.0
#
#                                  SCoV2_load DoubSing             celltype  \
# ma_d0_lung_1_AAACCCAGTGACTCGC-1         0.0  Singlet            Capillary
# ma_d0_lung_1_AAACGAAAGGATTCCT-1         0.0  Singlet          Neutrophils
# ma_d0_lung_1_AAACGAACAAGACAAT-1         0.0  Singlet               Bcells
# ma_d0_lung_1_AAACGCTAGACAAGCC-1         0.0  Doublet  AlveolarMacrophages
# ma_d0_lung_1_AAACGCTAGTATAGGT-1         0.0  Singlet  AlveolarMacrophages
#
# ...

# %%
# PhoRob
if True:
    dwarf_timecourse_data = scv.read(dwarf_timecourse)
    dwarf_timecourse_data.uns['name'] = 'Dwarfhamster_timecourse'
    dwarf_timecourse_data.obs['organism'] = 'Dwarfhamster'
    dwarf_timecourse_data.obs['dosage'] = ['high dose' if 'hd' in x else 'low dose' if 'ld' in x else 'no dose' for x in dwarf_timecourse_data.obs['orig.ident']]
    dwarf_timecourse_data.uns['dosage_colors'] = ['tab:red', 'tab:blue', 'tab:grey']  # high, low, no dose
    dwarf_timecourse_data.uns['timepoint_colors'] = ['tab:grey', 'lightcoral', 'tab:red', 'lightblue', 'tab:blue']  # D0, hd D2, hd D3, ld D2, ld D3
    dwarf_timecourse_data.obs['time'] = [x.split('_')[-1] for x in dwarf_timecourse_data.obs.timepoint]
    dwarf_timecourse_data.uns['time_colors'] = ['tab:grey', 'lightgreen', 'limegreen']  # D0, D2, D3
    dwarf_timecourse_data.obs['hamster'] = [x+'_pr' for x in dwarf_timecourse_data.obs.hamster]
    dwarf_timecourse_data.obs['severity'] = 'severe/critical'
    dwarf_timecourse_data.obs['sample_type'] = 'tissue'
    dwarf_timecourse_data.obs['3_or_5_prime'] = '3'
    dwarf_timecourse_data.obs['disease'] = 'COVID19'
    dwarf_timecourse_data.obs['SCoV2_detected'] = dwarf_timecourse_data.obs['SCoV2_sum'] > 0
    dwarf_timecourse_data.obs['sample_id'] = [x+'_'+y for x,y in zip(dwarf_timecourse_data.obs.hamster, dwarf_timecourse_data.obs.timepoint)]
    dwarf_timecourse_data.obs = dwarf_timecourse_data.obs.drop(['orig.ident', 'integrated_snn_res.0.5', 'seurat_clusters', 'nCount_SCT', 'nFeature_SCT', 'UMAP_1', 'UMAP_2', 'cell_id', 'endocytotox'], axis=1)
    dwarf_timecourse_data.obs=dwarf_timecourse_data.obs.rename({'nCount_RNA': 'ncounts', 'nFeature_RNA': 'ngenes'}, axis=1)

    # humanize genes
    dwarf_timecourse_data.var_names = [x.upper() for x in dwarf_timecourse_data.var_names]
    # dwarf_timecourse_data.var_names = specify_genes(dwarf_timecourse_data.var_names)
    # dwarf_timecourse_data = aggregate_duplicate_genes(dwarf_timecourse_data)
    # dwarf_timecourse_data.write(f'{data_path}PhoRob_timecourse/PhoRob_timecourse_all_humanized.h5')
else:
    dwarf_timecourse_data = sc.read(f'{data_path}PhoRob_timecourse/PhoRob_timecourse_all_humanized.h5')
print(dwarf_timecourse_data.X.shape, dwarf_timecourse_data.X.count_nonzero())
dwarf_timecourse_data.obs.head()
# Out:
# (40842, 18036) 71195673
#                                ncounts  ngenes timepoint hamster  SCoV2_sum  \
# pr_D0_Z1_L_AAACCCAGTCAGTCCG-1  14836.0  3813.0        D0  Ha1_pr        0.0
# pr_D0_Z1_L_AAACCCAGTGGTTTGT-1   3132.0  1167.0        D0  Ha1_pr        0.0
# pr_D0_Z1_L_AAACCCATCCTCACCA-1   4216.0  1625.0        D0  Ha1_pr        0.0
# pr_D0_Z1_L_AAACCCATCGTCAGAT-1   3036.0  1574.0        D0  Ha1_pr        0.0
# pr_D0_Z1_L_AAACGCTCAACTCGAT-1   3242.0  1247.0        D0  Ha1_pr        0.0
#
#                                SCoV2_load DoubSing            celltype  \
# pr_D0_Z1_L_AAACCCAGTCAGTCCG-1         0.0  Singlet            TNKcells
# pr_D0_Z1_L_AAACCCAGTGGTTTGT-1         0.0  Doublet              Bcells
# pr_D0_Z1_L_AAACCCATCCTCACCA-1         0.0  Singlet  Treml4+Macrophages
# pr_D0_Z1_L_AAACCCATCGTCAGAT-1         0.0  Singlet           Bronchial
# pr_D0_Z1_L_AAACGCTCAACTCGAT-1         0.0  Singlet              Bcells
#
# ...

# %% [markdown]
# # Merge

# %%
adatas = [dwarf_timecourse_data, gold_data, 
          MelmsIzar290421_data, RenZhang030221_data, SperanzaDeWit270121_data, LiaoZhang120520_data, WautersLambrecht210121_data, DeloreyRegev290421_data,
          WendischSander221221_LIBGEX, WendischSander221221_BAL,
          ChuaEils290620_data, BostBronte050321_data, GrantWunderink110121_data
         ]
all_genes = [list(d.var_names) for d in adatas]
common_genes = intersect_many(all_genes)
print(f'{len(common_genes)} genes were found in all datasets.')
# Out:
# 9903 genes were found in all datasets.

# %%
superdata = sc.concat({adata.uns['name']: adata[:, common_genes] for adata in adatas}, label='batch', index_unique='-', join='outer')
superdata.write('/fast/work/users/peidlis_c/data/Cov19Hamster/Cov19_merged_cross_species_commongenes.h5')

superdata = sc.concat({adata.uns['name']: adata for adata in adatas}, label='batch', index_unique='-', join='outer')
superdata.write('/fast/work/users/peidlis_c/data/Cov19Hamster/Cov19_merged_cross_species_allgenes.h5')

print('Finished merging!')
# Out:
# ... storing 'timepoint' as categorical
# ... storing 'hamster' as categorical
# ... storing 'celltype' as categorical
# ... storing 'dosage' as categorical
# ... storing 'time' as categorical
# ... storing 'doublet_types' as categorical
# ... storing 'organism' as categorical
# ... storing 'severity' as categorical
# ... storing 'sample_type' as categorical
# ... storing '3_or_5_prime' as categorical
# ... storing 'disease' as categorical
# ... storing 'sample_id' as categorical
# ... storing 'celltype_2' as categorical
# ... storing 'sex' as categorical
# ... storing 'outcome' as categorical
# ... storing 'comorbidities' as categorical
# ... storing 'treatment' as categorical
# ... storing 'patient' as categorical
# ... storing 'duration_to_outcome' as categorical
# ... storing 'WHO_Classification' as categorical
# ... storing 'timepoint' as categorical
# ... storing 'hamster' as categorical
# ... storing 'celltype' as categorical
# ... storing 'dosage' as categorical
# ...

# %% [markdown]
# # Meta analysis

# %%
keys = ['severity', 'organism', 'disease', 'batch', 'outcome', 'sample_type']
obses = {adata.uns['name']: adata.obs for adata in adatas}
for name in obses.keys():
    obses[name]['batch'] = name
all_obs = pd.concat(obses)
fig, axs = pl.subplots(2,3, figsize=[5 * 3, 5 * 2], dpi=120)
for key, ax in zip(keys, np.ravel(axs)):
    df = all_obs[key]
    df[pd.isna(df)]='None'
    df.value_counts().plot(kind='pie', ax=ax, autopct='%1.1f%%', textprops={'fontsize': 8})
    ax.set_ylabel('')
    ax.set_title(key)
pl.suptitle(f'Datasets overview\n{len(all_obs)} cells in total', fontsize=16)
# pl.tight_layout()
pl.savefig('../figures/Datasets_overview_pieplots.pdf')
pl.show()
